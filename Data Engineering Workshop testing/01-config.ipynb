# %%
# External Locations
base_dir_data = spark.sql("DESCRIBE EXTERNAL LOCATION `data-zone`").select("url").collect()[0][0]
base_dir_checkpoint = spark.sql("DESCRIBE EXTERNAL LOCATION `checkpoint-zone`").select("url").collect()[0][0]
